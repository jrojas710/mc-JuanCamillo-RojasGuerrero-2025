# %% [markdown]
# # Realizar las siguientes operaciones utilizando una notación de punto flotante en base 10 con un dígito para el signo del número, 4 dígitos para el exponente con signo y 7 dígitos para la mantisa:

# %% [markdown]
# ###a) 76.293,62 + 0,006979
# ###b) 832,074 - 60.719,005
# ###c) 0,52266 * 0,00012048
# ###d) 32,97138 / 0,000109635

# %% [markdown]
# ![1000147939.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![1000147940.jpg](data:image/jpeg;base64,...)
